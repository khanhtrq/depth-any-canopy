# %%
import rasterio
path = '../Mangrove CaMau data/Mask_CaMau.tif'

with rasterio.open(path) as src:
    img = src.read()

print(img.shape)
# Out:
# (1, 5514, 12628)

# %%
import numpy as np
np.unique(img)
# Out:
# array([1, 2, 3, 4, 5, 6], dtype=uint8)

# %%
(img == 6).sum() / img.size
# Out:
# 0.5174110183896803

# %%
import os
os.listdir('../Mangrove CaMau data/Mask_CaMau.tif')
# Out:
# ['INPUT_RAW', 'INPUT_RAW.rar', 'Mask_CaMau.tif', 'original paper.zip']
